# %% [markdown]
# ```
# ampersand/
# │
# ├── README.md
# │
# ├── docs/
# │   ├── data_preparation.ipynb
# │   ├── model_training.ipynb
# │   └── model_evaluation.ipynb
# │
# ├── data/
# │   ├── raw/
# │   │   ├── ML_training_data/
# │   │   └── user_interaction_data/
# │   └── processed/
# │       ├── ML_training_data/
# │       ├── user_interaction_data/
# │       ├── translation_memory/
# │       └── knowledge_base/
# │
# ├── ux/
# │   └── ...
# │
# ├── tests/
# │   ├── ...
# ├── src/
# │   ├── __init__.py
# │   ├── ampersand.py # (or manage.py if Django)
# │   │
# │   ├── api/
# │   │   ├── __init__.py
# │   │   ├── ...
# │   │   └── <api_modules.py>/
# │   │
# │   ├── ml/
# │   │
# │   ├── hci/
# │   │   ├── cl/
# │   │   │   ├── __init__.py
# │   │   │   ├── grammar_induction.py
# │   │   │   ├── semantics.py
# │   │   │   ├── semiotics.py
# │   │   │   ├── discourse_analysis.py
# │   │   │   ├── lexicostatistics.py
# │   │   ├── nlp/
# │   │   │   ├── __init__.py
# │   │   │   ├── sentiment_analysis.py
# │   │   │   ├── logic_translation.py
# │   │   │   ├── disambiguation.py
# │   │   │   └── parcing.py
# │   │   │
# │   │   └── dialog/
# │   │       ├── __init__.py
# │   │       ├── response_frameworks.py
# │   │       ├── bidirectional_prompts.py
# │   │       ├── response_generator.py
# │   │       └── user_session.py
# │   │
# │   │
# │   ├── data_analytics/
# │   │   ├── inputs/
# │   │   │   ├── preprocessing.py
# │   │   │   └── feature_engineering.py
# │   │   ├── data_science/
# │   │   │   ├── statistics/
# │   │   │   │   ├── descriptive.py
# │   │   │   │   ├── inferential.py
# │   │   │   │   ├── bayesian.py
# │   │   │   │   ├── regression.py
# │   │   │   │   ├── classification.py
# │   │   │   │   └── ensemble_methods.py
# │   │   │   ├── information_theory/
# │   │   │   │   ├── entropy.py
# │   │   │   │   ├── inferential.py
# │   │   │   │   └── mutual_dependency.py
# │   │   │   ├── mathematics/
# │   │   │   │   ├── linear_algebra.py
# │   │   │   │   ├── calculus.py
# │   │   │   │   └── optimization.py
# │   │   │   ├── deep_learning/
# │   │   │   │   ├── neural_networks.py
# │   │   │   │   ├── convolutional_nn.py
# │   │   │   │   ├── recurrent_nn.py
# │   │   │   │   └── transformers.py
# │   │   │   └── reinforcement/
# │   │   │       ├── q_learing.py
# │   │   │       ├── actor_critic.py
# │   │   │       ├── a3c.py
# │   │   │       ├── ppo.py
# │   │   │       ├── td3.py
# │   │   │       ├── sac.py
# │   │   │       └── policy_gradients.py
# │   │   ├── visualization/
# │   │   │   ├── libraries.py
# │   │   │   └── ...
# │   │   ├── businees_intelligence/
# │   │   │   ├── report.py
# │   │   │   ├── warehouse.py
# │   │   │   ├── etl_process.py
# │   │   │   ├── predict.py
# │   │   │   ├── customer.py
# │   │   │   ├── market_basket.py
# │   │   │   ├── financial_forecasting.py
# │   │   │   ├── opinion_mining.py # utilizes core/nlp/sentiment_analysis.py
# │   │   │   ├── risk_management.py
# │   │   │   ├── employee_kpi.py
# │   │   │   └── biz_ops.py
# │   │   ├── data_utils/
# │   │   │   ├── loaders.py
# │   │   │   └── math_ancillary.py
# │   │   └── lab/
# │   │       ├── model_testing.py
# │   │       └── performance_metrics.py
# │   │
# │   └── utils/
# │       ├── __init__.py
# │       ├── context_management.py
# │       ├── logger.py
# │       ├── validator.py
# │       └── learning_modules/
# │
# ├── services/
# │   ├── ...
# │   └── Azure/
# │
# ├── config/
# │   ├── ...
# │   └── azure_config.json
# │
# └── requirements.txt
# ```
