# %% [markdown]
# ```
# ampersand/
# │
# ├── README.md
# │
# ├── docs/
# │   ├── architecture.ipynb                  # You are here!
# │   ├── django.ipynb
# │   ├── postgresql.ipynb
# │   └── ...
# │
# ├── src/
# │   ├── django_directory/
# │   │   ├── __init__.py
# │   │   ├── asgi.py
# │   │   ├── settings.py                         # Settings for Django
# │   │   ├── urls_django.py                      # Project-level URL declarations
# │   │   └── wsgi.py
# │   │
# │   └── core/
# │       ├── user/
# │       │   ├── migrations_user/
# │       │   ├── models_user.py
# │       │   ├── views_user.py
# │       │   ├── urls_user.py
# │       │   └── ...
# │       │
# │       ├── hci/
# │       │   ├── migrations_hci/
# │       │   ├── static/
# │       │   │   └── css/
# │       │   │       └── ...                         # CSS files for hci
# │       │   ├── templates/
# │       │   │   └── templates_hci/
# │       │   │       └── ...                         # HTML templates
# │       │   ├── admin.py
# │       │   ├── models_hci.py
# │       │   ├── views_hci.py
# │       │   ├── urls_hci.py
# │       │   └── ...
# │       │
# │       ├── memory/
# │       │   ├── migrations_memory/
# │       │   ├── models_memory.py
# │       │   ├── views_memory.py
# │       │   └── ...
# │       │
# │       ├── analytics/
# │       │   ├── migrations_analytics/
# │       │   ├── models_analytics.py
# │       │   ├── views_analytics.py
# │       │   └── ...
# │       │
# │       └── ux/
# │           ├── static/
# │           │   ├── css/
# │           │   │   └── custom.css
# │           │   ├── img/
# │           │   └── js/
# │           ├── templates_ux/
# │           └── ...
# │
# ├── static/
# │   ├── admin/
# │   ├── css/
# │   │   └── design_system.css
# │   ├── img/
# │   └── js/
# │
# ├── templates/
# │   └── base.thml
# │
# ├── utilities/
# │   ├── openai.py
# │   └── ...
# │
# ├── venv/
# ├── .gitignore
# ├── db.sqlite3
# ├── manage.py
# ├── requirements.txt
# └── azure_deploy.py
# ```
